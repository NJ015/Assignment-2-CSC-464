# %% [markdown]
# # Model

# %%
import pandas as pd
import numpy as np
import re
import random
from collections import defaultdict
from tqdm import tqdm

# Load Reuters dataset
dialogs = pd.read_csv("sample_reuters_dataset.csv")

# Clean the dataset
def clean_text(text):
    text = re.sub("[^a-zA-Z' ]", "", text)  # Keep only letters, spaces, and apostrophes
    return text.lower()

# Clean all sentence_text in the dialogs dataframe
dialogs['cleaned_text'] = dialogs['sentence_text'].apply(clean_text)

# creating the vocabulary
# get list of all the words
all_words = " ".join(dialogs['cleaned_text']).split()
words_dict = {}
# add word-count pair to the dictionary
for word in all_words:
    # check if the word is already in dictionary
    if word in words_dict:
        # increment count of word by 1
        words_dict[word] = words_dict[word] + 1
    else:
        # add the word to dictionary with count 1
        words_dict[word] = 1


# Create N-grams functions
def create_ngram(sentence, n):
    tokens = sentence.split()
    return [tokens[i:i + n] for i in range(len(tokens) - n + 1)]

# Create dataframe with cleaned sentences and N-grams
dataset = pd.DataFrame({'Sentences': dialogs['cleaned_text']})
dataset['unigram'] = dataset['Sentences'].apply(lambda x: create_ngram(x, 1))
dataset['bigram'] = dataset['Sentences'].apply(lambda x: create_ngram(x, 2))
dataset['trigram'] = dataset['Sentences'].apply(lambda x: create_ngram(x, 3))

# Build N-gram model (trigrams in this case)
model = defaultdict(lambda: defaultdict(lambda: 0))
for trigrams in dataset['trigram']:
    for w1, w2, w3 in trigrams:
        model[(w1, w2)][w3] += 1

# Convert counts to probabilities
for w1_w2 in model:
    total_count = float(sum(model[w1_w2].values()))
    for w3 in model[w1_w2]:
        model[w1_w2][w3] /= total_count

# Function to predict the next word based on the trigram model
def predict_next_word(w1, w2, model):
    if (w1, w2) in model:
        return max(model[(w1, w2)], key=model[(w1, w2)].get)
    else:
        return "No prediction available"

print(dict(model["am", "concerned"]))
# Out:
# {'and': 0.5, 'that': 0.5}

# %%
# Create vocabulary
vocabulary = set(" ".join(dialogs['cleaned_text']).split())
print(f"Vocabulary size: {len(vocabulary)}")
print(f"Vocabulary: {vocabulary}")
# Out:
# Vocabulary size: 12580
# Vocabulary: {'emergency', 'cper', 'onset', 'floating', 'evaluating', 'peso', 'settled', 'application', 'lived', 'requesting', 'actively', 'speculator', 'tf', 'dockers', 'ericy', 'icbi', 'insures', 'busy', 'duck', 'belo', 'phyt', 'enormous', 'assurances', 'residents', 'overture', 'focused', 'pentland', 'crew', 'henry', 'valid', 'compelled', 'projection', 'vibrancy', 'questioned', 'permissible', 'fuelled', 'sti', 'exclusivity', 'concerning', 'mmm', 'names', 'bolstering', 'texitle', 'ferraz', 'nza', 'amended', 'boothe', 'question', 'petrodollar', 'removes', 'hurricane', 'animal', 'lome', 'modernization', 'paints', 'marginal', 'metalurgicos', 'spell', 'disputes', 'ssoa', 'mainframe', 'upheld', 'print', 'quaker', 'simultaneously', 'mitsubishi', 'conservation', 'shinji', 'jones', 'bill', 'leads', 'kokusai', 'certificates', 'quickly', 'reinstatement', 'br', 'wmtt', 'bildner', 'nutritious', 'comprise', 'chyn', 'settle', 'pacific', 'shelters', 'closing', 'abbk', 'amicable', 'qabas', 'buses', 'are', 'wyoming', 'falling', 'aren', 'regions', 'postion', 'revaluation', 'acquisition', 'record', 'moss', 'pc', 'spot', 'alongside', 'organizations', 'reappointed', 'ente', 'odessa', 'spartech', 'ncty', 'personnel', 'lowers', 'younger', 'content', 'kasch', 'deserve', 'necessary', 'malt', 'wcix', 'derivative', 'changing', 'specifically', 'outflows', 'spika', 'manner', 'frampton', 'sperry', 'armel', 'cutrale', 'bil', 'trades', 'materials', 'care', 'household', 'whitten', 'supporters', 'calculated', 'iu', 'tiered', 'inview', 'unresolved', 'comm', 'gna', 'audit', 'eni', 'entg', 'school', 'zealand', 'comminuique', 'procedural', 'psm', 'thera', 'might', 'own', 'restrained', 'leak', 'rash', 'muscles', 'fn', 'api', 'jewellery', 'sprh', 'varzi', 'postpone', 'whirlpool', 'casualty', 'rapidly', 'prefer', 'prevail', 'ousting', 'waterway', 'greeted', 'negligible', 'prepackers', 'yld', 'recalled', 'midl', 'labelling', 'channel', 'rich', 'ky', 'mobiliere', 'antagonize', 'gebrueder', 'steaks', 'depositors', 'battles', 'carsey', 'exlude', 'nabisco', 'divestiture', 'raycomm', 'gather', 'mike', 'four', 'doubts', 'ourselves', 'catalog', 'salomon', 'tender', 'resistance', 'overreaction', 'forum', 'muted', 'emerged', 'withheld', 'ffbn', 'modular', 'come', 'served', 'anticancer', 'unnoticed', 'pzl', 'win', 'exhausted', 'concerned', 'reasonably', 'efh', 'experience', 'hermiston', 'revoked', 'net', 'technological', 'least', 'disclosure', 'sarawak', 'approaching', 'entries', 'greenville', 'sticking', 'parcels', 'mite', 'ciif', 'barber', 'produc', 'stats', 'migrating', 'dmp', 'reacting', 'extraordinary', 'affirmed', 'consultation', 'geurin', 'portable', 'herriot', 'lawmakers', 'markka', 'hansen', 'company', 'meat', 'midwestern', 'barricini', 'everywhere', 'cross', 'concerted', 'opposes', 'contractual', 'monsanto', 'polices', 'though', 'pancanadian', 'williams', 'underwriting', 'morrison', 'kennecott', 'portrayed', 'osp', 'basicly', 'yielding', 'particpation', 'impossible', 'proxy', 'clothing', 'thought', 'understands', 'rightful', 'televised', 'lf', 'judging', 'implications', 'tetsuo', 'aerospace', 'misc', 'f', 'press', 'qassem', 'rothmans', 'fip', 'ferrous', 'fhr', 'subscriptions', 'ua', 'connect', 'ktxh', 'declaring', 'pattern', 'gov', 'warren', 'regulate', 'overfunding', 'petroleums', 'transitory', 'mad', 'sides', 'characterised', 'population', 'kembla', 'doubt', 'distributed', 'mgcr', 'bottler', 'synar', 'glut', 'baseload', 'baii', 'erickson', 'paramus', 'molybdenum', 'competence', 'pincus', 'calculating', 'aron', 'quoting', 'nosedive', 'contracting', 'fire', 'replace', 'suspicion', 'collects', 'spirits', 'helpful', 'gave', 'forstmann', 'mechanical', 'that', 'hideo', 'dailies', 'holders', 'lacklustre', 'publicize', 'assuming', 'ministries', 'outer', 'jute', 'can', 'baht', 'bankeast', 'underwritten', 'loaned', 'paton', 'panels', 'decry', 'tbc', 'community', 'bulgaria', 'music', 'cattle', 'influenced', 'modules', 'covering', 'rican', 'implementing', 'olsen', 'spotlights', ...

# %%
dataset.head()
# Out:
#                                            Sentences  \
# 0  asian exporters fear damage from u  s  japan r...
# 1  they told reuter correspondents in asian capit...
# 2  but some exporters said that while the conflic...
# 3  the u  s  has said it will impose  mln dlrs of...
# 4  unofficial japanese estimates put the impact o...
#
#                                              unigram  \
# 0  [[asian], [exporters], [fear], [damage], [from...
# 1  [[they], [told], [reuter], [correspondents], [...
# 2  [[but], [some], [exporters], [said], [that], [...
# 3  [[the], [u], [s], [has], [said], [it], [will],...
# 4  [[unofficial], [japanese], [estimates], [put],...
#
#                                               bigram  \
# 0  [[asian, exporters], [exporters, fear], [fear,...
# 1  [[they, told], [told, reuter], [reuter, corres...
# 2  [[but, some], [some, exporters], [exporters, s...
# 3  [[the, u], [u, s], [s, has], [has, said], [sai...
# 4  [[unofficial, japanese], [japanese, estimates]...
#
#                                              trigram
# 0  [[asian, exporters, fear], [exporters, fear, d...
# 1  [[they, told, reuter], [told, reuter, correspo...
# 2  [[but, some, exporters], [some, exporters, sai...
# 3  [[the, u, s], [u, s, has], [s, has, said], [ha...
# 4  [[unofficial, japanese, estimates], [japanese,...

# %% [markdown]
# # Evaluation

# %%
def evaluate_accuracy(model, test_sentences):
    correct = 0
    total = 0

    for sentence in test_sentences:
        words = sentence.split()
        for i in range(len(words) - 2):
            w1, w2, actual_next = words[i], words[i+1], words[i+2]
            predicted_next = predict_next_word(w1, w2, model)
            if predicted_next == actual_next:
                correct += 1
            total += 1

    return correct / total if total > 0 else 0

# Example test sentences
test_sentences = ["global economy is strong","i have been","we are still","they will be"]

print("Prediction Accuracy:", evaluate_accuracy(model, test_sentences))
# Out:
# Prediction Accuracy: 0.8

# %%
import numpy as np

def calculate_perplexity(model, test_sentences):
    total_log_prob = 0
    total_words = 0

    for sentence in test_sentences:
        words = sentence.split()
        trigrams = create_ngram(sentence, 3)
        sentence_prob = 1

        for w1, w2, w3 in trigrams:
            if (w1, w2) in model and w3 in model[(w1, w2)]:
                sentence_prob *= model[(w1, w2)][w3]
            else:
                sentence_prob *= 1e-6  # Smoothing for unseen words

        total_log_prob += np.log(sentence_prob)
        total_words += len(words)

    perplexity = np.exp(-total_log_prob / total_words)
    return perplexity

# Example test sentences
test_data = ["stock market is rising", "global economy is improving"]
print("Perplexity:", calculate_perplexity(model, test_data))
# Out:
# Perplexity: 177.82794100389225

# %%
from nltk.translate.bleu_score import sentence_bleu, SmoothingFunction
import numpy as np

# Function to predict the next word (replace with your actual model logic)
def predict_next_word(w1, w2, model):
    # Check if the bigram (w1, w2) exists in the model
    if (w1, w2) in model:
        # Get the most likely next word based on probabilities
        return max(model[(w1, w2)], key=model[(w1, w2)].get)
    else:
        # Return "unknown" if the bigram is not found
        return "unknown"

def evaluate_bleu(model, reference_sentences):
    scores = []
    smoothie = SmoothingFunction().method1  # Apply smoothing

    for sentence in reference_sentences:
        words = sentence.lower().split()

        for i in range(len(words) - 2):  # Loop through bigrams
            w1, w2, actual_next_word = words[i], words[i + 1], words[i + 2]
            predicted_word = predict_next_word(w1, w2, model)  # Use the actual predict_next_word function

            if predicted_word == "unknown":
                continue  # Skip if model fails to predict

            generated_tokens = [w1, w2, predicted_word]  # Model's output
            reference_tokens = [[w1, w2, actual_next_word]]  # Expected

            # Calculate BLEU for this prediction (unigrams & bigrams only)
            score = sentence_bleu(reference_tokens, generated_tokens, weights=(0.5, 0.5, 0, 0), smoothing_function=smoothie)
            scores.append(score)

    return np.mean(scores) if scores else 0  # Avoid division by zero

# Example reference sentences
reference_data = ["Market volatility impacts investor confidence", "Economic growth remains a key priority"]

# Convert defaultdict to a normal dictionary before passing to evaluation
model_dict = {tuple(k): dict(v) for k, v in model.items()}  # Convert keys to tuples

# Run evaluation using the converted model
print("BLEU Score:", evaluate_bleu(model_dict, reference_data))
# Out:
# BLEU Score: 0.5773502691896257

# %% [markdown]
# # Testing

# %%
# another example
dict(model["how", "are"])
# Out:
# {'european': 1.0}

# %%
# another example
dict(model["good", "to"])
# Out:
# {'go': 0.3333333333333333,
#  'have': 0.3333333333333333,
#  'very': 0.3333333333333333}

# %%
dict(model["to", "very"])
# Out:
# {'good': 1.0}

# %%
dict(model["i", "have"])
# Out:
# {'nothing': 0.16666666666666666,
#  'been': 0.3333333333333333,
#  'mixed': 0.16666666666666666,
#  'to': 0.16666666666666666,
#  'talked': 0.16666666666666666}

# %% [markdown]
# # Saving

# %%
import pickle

# Convert defaultdict to normal dict
model_dict = {k: dict(v) for k, v in model.items()}

# Save model
with open("trigram_model.pkl", "wb") as f:
    pickle.dump(model_dict, f)

print("Model saved successfully!")
# Out:
# Model saved successfully!
